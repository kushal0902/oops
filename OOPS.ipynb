# %% [markdown]
# <a href="https://colab.research.google.com/github/kushal0902/oops/blob/main/OOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class bankaccount :
  def __init__(self,amount , name, age, account_no ):
    self.amount = amount
    self.name= name
    self.age= age
    self.account_no= account_no
  def amount(self):
    if self.amount<0:
      print("amount cant be -tive" )
    else:
      print(f"your amount is :{self.amount}")
  def deposite(self,amount):
    self.amount+=amount
    print(f"your new amount is {self.amount}")
  def withdraw(self,amount):
    self.amount-=amount
    print(f"paise kat gyee")

acc1 = bankaccount(100,"rastogi",12,123)
acc1.deposite(10)
acc1.withdraw(500)
# Out:
# your new amount is 110
# paise kat gyee
