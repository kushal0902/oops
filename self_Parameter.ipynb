# %% [markdown]
# <a href="https://colab.research.google.com/github/kushal0902/oops/blob/main/self_Parameter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a class called Car
#
# Add an __init__ method with a brand parameter, and store it as a property
#
# Add a method called show that prints the brand
#
# Create an object c1 of the Car class with brand "Ford"
#
# Call the show method on c1

# %%
class car:
  def __init__(self,brand):
    self.brand= brand
  def show(self):
    print(f"your brand name is",self.brand)
c1=car("ford")
c1.show()
# Out:
# your brand name is ford
